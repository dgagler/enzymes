# %% [markdown]
# # Spirea Creek plots from Hot Life 2018
# So many geochemical plots. Some thermo in there too.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

# %%
### reading main csv
df = pd.read_csv('spireacreek.csv')

### logKs between T = 25-225 at 25 deg intervals to create equilib line
### cleaning up df to just have T and logK
caco3_logKs = pd.read_csv('CaCO3_logKs.csv')
caco3_logKs['T'] = [0,25,50,75,100,125,150,175,200,225]
caco3_logKs = caco3_logKs.rename(columns={'x': 'logK'})
caco3_logKs = caco3_logKs.drop('Unnamed: 0', 1)

### reading comparison csv
comp = pd.read_csv('HotLife_comparison_springs.csv')
compnames = comp['Sample Location']
comparea = comp['Sampling area']
comptemp = comp['Cond Temp']
df.columns
# Out:
# Index(['Sample ID', 'Sample Location', 'pH', 'Cond.', 'Flash. Cond.',
#        'Cond Temp', 'Elevation', 'DIC', 'DIC.1', 'DIC.2', 'DIC.3', 'DIC.4',
#        'DOC', 'DOC.1', 'DOC.2', 'DOC.3', 'DOC.4', 'D.O.', 'Fe+2(mg/L)',
#        'Fe+2(M)', 'S-2(ug/L)', 'S-2(M)', 'SiO2', 'SiO2.1', 'CaCO3', 'CaCO3.1',
#        'F-', 'F-.1', 'F-.2', 'Cl-', 'Cl-.1', 'Cl-.2', 'Br-', 'Br-.1', 'Br-.2',
#        'SO4-2', 'SO4-2.1', 'SO4-2.2', 'NO2-', 'NO2-.1', 'NO2-.2', 'NO3-',
#        'NO3-.1', 'NO3-.2', 'Li+', 'Li+.1', 'Li+.2', 'Na+', 'Na+.1', 'Na+.2',
#        'NH4+', 'NH4+.1', 'NH4+.2', 'K+', 'K+.1', 'K+.2', 'Mg+2', 'Mg+2.1',
#        'Mg+2.2', 'Ca+2', 'Ca+2.1', 'Ca+2.2'],
#       dtype='object')

# %%
m = np.arange(4)
mi = len(m)

spirea_names = df['Sample Location']
labels = spirea_names

spirea_pH = df['pH']
spirea_temp = df['Cond Temp']
spirea_DIC = df['DIC']
spirea_ammonium = df['NH4+.1']
spirea_nitrite = df['NO2-.1']
spirea_nitrate = df['NO3-.1']
spirea_chloride = df['Cl-.1']
spirea_sulfate = df['SO4-2.1']
spirea_totalsulfide = df['S-2(ug/L)']
spirea_sulfide = spirea_totalsulfide/1000000/34
spirea_flouride = df['F-.1']
spirea_bromide = df['Br-.1']
spirea_lithium = df['Li+.1']
spirea_sodium = df['Na+.1']
spirea_potassium = df['K+.1']
spirea_magnesium = df['Mg+2.1']
spirea_calcium = df['Ca+2.1']

# %%
spirea_sulfide
# Out:
# 0    5.882353e-08
# 1    5.882353e-08
# 2    8.823529e-08
# 3    1.176471e-07
# Name: S-2(ug/L), dtype: float64

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_calcium[i], 'ko')
    plt.ylabel('Ca+2 (mol/kg)')
    plt.xticks(m, labels)
    plt.title('Ca+2 at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-calcium')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_magnesium[i], 'ko')
    plt.ylabel('Mg+2 (mol/kg)')
    plt.xticks(m, labels)
    plt.title('Mg+2 at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-magnesium')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_potassium[i], 'ko')
    plt.ylabel('K+ (mol/kg)')
    plt.xticks(m, labels)
    plt.title('K+ at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-potassium')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_sodium[i], 'ko')
    plt.ylabel('Na+ (mol/kg)')
    plt.xticks(m, labels)
    plt.title('Na+ at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-sodium')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_lithium[i], 'ko')
    plt.ylabel('Li+ (mol/kg)')
    plt.xticks(m, labels)
    plt.title('Li+ at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-lithium')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_bromide[i], 'ko')
    plt.ylabel('Br- (mol/kg)')
    plt.xticks(m, labels)
    plt.title('Br- at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-bromide')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_flouride[i], 'ko')
    plt.ylabel('Fl- (mol/kg)')
    plt.xticks(m, labels)
    plt.title('Fl- at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-flouride')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_sulfide[i], 'ko')
    plt.ylabel('Total sulfide (mol/kg)')
    plt.xticks(m, labels)
    plt.title('Total sulfide at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-sulfide')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_sulfate[i], 'ko')
    plt.ylabel('SO4-2 (mol/kg)')
    plt.xticks(m, labels)
    plt.title('SO4-2 at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-sulfate')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_chloride[i], 'ko')
    plt.ylabel('Cl- (mol/kg)')
    plt.xticks(m, labels)
    plt.title('Cl- at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-chloride')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_nitrate[i], 'ko')
    plt.ylabel('NO3- (mol/kg)')
    plt.xticks(m, labels)
    plt.title('NO3- at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-nitrate')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_nitrite[i], 'ko')
    plt.ylabel('NO2- (mol/kg)')
    plt.xticks(m, labels)
    plt.title('NO2- at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-nitrite')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_ammonium[i], 'ko')
    plt.ylabel('NH4+ (mol/kg)')
    plt.xticks(m, labels)
    plt.title('NH4+ at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-ammonium')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_DIC[i], 'ko')
    plt.ylabel('DIC (ppmC)')
    plt.xticks(m, labels)
    plt.title('DIC at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-DIC')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_temp[i], 'ko')
    plt.ylabel('Temperature (°C)')
    plt.xticks(m, labels)
    plt.title('Temperature at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-temp')

# %%
for i in np.arange(4):
    plt.plot(m[i], spirea_pH[i], 'ko')
    plt.ylabel('pH')
    plt.xticks(m, labels)
    plt.title('pH at Spirea Creek')
    plt.tight_layout()
    plt.savefig('spirea-pH')

# %%
### reading the log activities acquired from the AquaMine notebook
spirea_activities = pd.read_csv('spirea_aq_log_activity.csv')
bison_activities = pd.read_csv('bison2014_aq_log_activity.csv')
comparison_activities = pd.read_csv('comparisons_aq_log_activity.csv')
### dropping unnecessary columns
comparison_activities = comparison_activities.drop('Unnamed: 0', 1)
comparison_activities = comparison_activities.drop('sample', 1)

# %%
### only need to use this line once otherwise it starts pulling errors
comparison_activities.insert(loc=1, column='Sample Name', value=compnames)
#comparison_activities

# %%
### extracting the Ca+2 and CO3-2 activities from the AquaMine output
spirea_Ca = spirea_activities['Ca+2']
spirea_CO3 = spirea_activities['CO3-2']
bison_Ca = bison_activities['Ca+2']
bion_CO3 = bison_activities['CO3-2']
comparison_Ca = comparison_activities['Ca+2']
comparison_CO3 = comparison_activities['CO3-2']

### Qs and Ts for each spring at Spirea
HoJ_CaCO3_Q = spirea_Ca[0] + spirea_CO3[0]
HoJ_T = 43.9
HS_CaCO3_Q = spirea_Ca[1] + spirea_CO3[1]
HS_T = 47.1
GM_CaCO3_Q = spirea_Ca[2] + spirea_CO3[2]
GM_T = 66.6
BB_CaCO3_Q = spirea_Ca[3] + spirea_CO3[3]
BB_T = 62.2

spirea_Qs = [HoJ_CaCO3_Q, HS_CaCO3_Q, GM_CaCO3_Q, BB_CaCO3_Q]
spirea_Ts = [HoJ_T, HS_T, GM_T, BB_T]

# %%
### creating a list in which to place the logQs from the comparison sheet
### would be nice to make this a generalized function...not now tho
comparison_logQs = []
calcium = comparison_activities['Ca+2']
carbonate = comparison_activities['CO3-2']
for i, j in zip(calcium, carbonate):
    q = i + j
    comparison_logQs.append(q)
#comparison_activities['logQ'] = comparison_logQs

### also only needs to be run once, inserting logQ and T into new df
comparison_activities.insert(loc=2, column='logQ', value=comparison_logQs)
comparison_activities.insert(loc=2, column='temp', value=comptemp)

# %%
### function which takes a pandas DF log activity sheet and pulls out carbonate Qs for each spring
### requires previously created array for storage
### NOT FUNCTIONAL ATM
def get_Qs(activity_sheet):
    new = activity_sheet[['Ca+2', 'CO3-2']].copy()
    calcium = new['Ca+2']
    carbonate = new['CO3-2']
    storage = []
    ### use zip function to iterate through both calcium and carb and calculate Q
    for i, j in zip(calcium, carbonate):
        q = i + j
    new['logQ'] = storage
    print(new)

# %%
comp_logQs = comparison_activities['logQ']
comp_names = comparison_activities['Sample Name']
n = len(comparison_activities['Ca+2'])

# %%
### test plot ###
n = len(comparison_activities['Ca+2'])

for i in np.arange(n):
    plt.plot(comptemp[i], comp_logQs[i], 'go', label=comp_names[i])
    plt.xlabel('temp')
    plt.ylabel('logQ')
    #plt.legend(loc='best')

# %%
f, ax = plt.subplots(figsize=(8,6))
ax.plot(caco3_logKs['T'], caco3_logKs['logK'], 'b-', label='CaCO3 Equilibrium')
ax.plot(spirea_Ts[0], spirea_Qs[0], 'ro', label='Heart of Joy')
ax.plot(spirea_Ts[1], spirea_Qs[1], 'mo', label='Hat Stew')
ax.plot(spirea_Ts[2], spirea_Qs[2], 'yo', label='Green Machine')
ax.plot(spirea_Ts[3], spirea_Qs[3], 'co', label='Bubble Boy')
for i in np.arange(n):
    c = cm.viridis(i/12.5)
    plt.plot(comptemp[i], comp_logQs[i], 's', color=c, label=comp_names[i])
    plt.legend(loc='best')
plt.xlabel('Temp(°C)')
plt.ylabel('logK')
ax.legend(loc='best')
plt.tight_layout()
plt.savefig('full_carbonate_equilibrium')

# %%
### defining subset data and reindexing arrays ###
whitecreek_names = compnames[0:6]; whitecreek_names.index = range(len(whitecreek_names))
whitecreek_temps = comptemp[0:6]; whitecreek_temps.index = range(len(whitecreek_temps))
whitecreek_logQs = comp_logQs[0:6]; whitecreek_logQs.index = range(len(whitecreek_logQs))

wahb_names = compnames[10:]; wahb_names.index = range(len(wahb_names.index))
wahb_temps = comptemp[10:]; wahb_temps.index = range(len(wahb_temps.index))
wahb_logQs = comp_logQs[10:]; wahb_logQs.index = range(len(wahb_logQs))


turbid_names = compnames[6:10]; turbid_names.index = range(len(turbid_names))
turbid_temps = comptemp[6:10]; turbid_temps.index = range(len(turbid_temps))
turbid_logQs = comp_logQs[6:10]; turbid_logQs.index = range(len(turbid_logQs))

# %%
print(len(whitecreek_names))
print(len(wahb_names))
print(len(turbid_names))
wahb_names.index = range(len(wahb_names.index))
wahb_names
# Out:
# 6
# 4
# 4
# 0    Fracking Calcite
# 1          Blue Steel
# 2         Cache Creek
# 3        Fist of Iron
# Name: Sample Location, dtype: object

# %%
### white creek comparison plot
f, ax = plt.subplots(figsize=(8,6))
ax.plot(caco3_logKs['T'], caco3_logKs['logK'], 'b-', label='CaCO3 Equilibrium')
ax.plot(spirea_Ts[0], spirea_Qs[0], 'ro', label='Heart of Joy')
ax.plot(spirea_Ts[1], spirea_Qs[1], 'mo', label='Hat Stew')
ax.plot(spirea_Ts[2], spirea_Qs[2], 'yo', label='Green Machine')
ax.plot(spirea_Ts[3], spirea_Qs[3], 'co', label='Bubble Boy')
for i in np.arange(6):
    c = cm.inferno(i/8)
    plt.plot(whitecreek_temps[i], whitecreek_logQs[i], 's', color=c, label=whitecreek_names[i])
    plt.legend(loc='best')
plt.xlabel('Temp(°C)')
plt.ylabel('logK')
plt.title('Spirea and White Creek')
ax.legend(loc='best')
plt.tight_layout()
plt.savefig('vswhitecreek_carbonate_equilibrium')

# %%
### wahb comparison plot
f, ax = plt.subplots(figsize=(8,6))
ax.plot(caco3_logKs['T'], caco3_logKs['logK'], 'b-', label='CaCO3 Equilibrium')
ax.plot(spirea_Ts[0], spirea_Qs[0], 'ro', label='Heart of Joy')
ax.plot(spirea_Ts[1], spirea_Qs[1], 'mo', label='Hat Stew')
ax.plot(spirea_Ts[2], spirea_Qs[2], 'yo', label='Green Machine')
ax.plot(spirea_Ts[3], spirea_Qs[3], 'co', label='Bubble Boy')
for i in np.arange(len(wahb_names)):
    c = cm.plasma(i/3)
    plt.plot(wahb_temps[i], wahb_logQs[i], 's', color=c, label=wahb_names[i])
    plt.legend(loc='best')
plt.xlabel('Temp(°C)')
plt.ylabel('logK')
plt.title('Spirea and Wahb')
ax.legend(loc='best')
plt.tight_layout()
plt.savefig('vswahb_carbonate_equilibrium')

# %%
### turbid lake comparison plot
f, ax = plt.subplots(figsize=(8,6))
ax.plot(caco3_logKs['T'], caco3_logKs['logK'], 'b-', label='CaCO3 Equilibrium')
ax.plot(spirea_Ts[0], spirea_Qs[0], 'ro', label='Heart of Joy')
ax.plot(spirea_Ts[1], spirea_Qs[1], 'mo', label='Hat Stew')
ax.plot(spirea_Ts[2], spirea_Qs[2], 'yo', label='Green Machine')
ax.plot(spirea_Ts[3], spirea_Qs[3], 'co', label='Bubble Boy')
for i in np.arange(len(turbid_names)):
    c = cm.inferno(i/8)
    plt.plot(turbid_temps[i], turbid_logQs[i], 's', color=c, label=turbid_names[i])
    plt.legend(loc='best')
plt.xlabel('Temp(°C)')
plt.ylabel('logK')
plt.title('Spirea and Turbid Lake')
ax.legend(loc='best')
plt.tight_layout()
plt.savefig('vsturbid_carbonate_equilibrium')

# %%
### just spirea carbonate equliibrium plot
f, ax = plt.subplots(figsize=(8,6))
ax.plot(caco3_logKs['T'], caco3_logKs['logK'], 'b-', label='CaCO3 Equilibrium')
ax.plot(spirea_Ts[0], spirea_Qs[0], 'ro', label='Heart of Joy')
ax.plot(spirea_Ts[1], spirea_Qs[1], 'mo', label='Hat Stew')
ax.plot(spirea_Ts[2], spirea_Qs[2], 'yo', label='Green Machine')
ax.plot(spirea_Ts[3], spirea_Qs[3], 'co', label='Bubble Boy')
plt.xlabel('Temp(°C)')
plt.ylabel('logK')
plt.title('Spirea')
ax.legend(loc='best')
plt.tight_layout()
plt.savefig('spirea_carbonate_equilibrium')

# %%
comp.columns
# Out:
# Index(['Sample ID', 'Sample Location', 'Year sampled', 'Sampling area', 'pH',
#        'pH.1', 'pH Temp', 'Cond.', 'Flash. Cond.', 'Cond Temp',
#        ...
#        'Unnamed: 238', 'Unnamed: 239', 'Unnamed: 240', 'Unnamed: 241',
#        'Unnamed: 242', 'DO (meter)', 'uncertainty', 'DO temp.', 'Unnamed: 246',
#        'Unnamed: 247'],
#       dtype='object', length=248)

# %%
#l = np.arange(len(comparison_nitrite))
labels2 = compnames
#comparison_nitrite = comp['NO2-']
#comparison_nitrate = comp['NO3-']
#comparison_pH = comp['pH']

# %%
#for i in l:
#    plt.plot(l[i], comparison_pH[i], 'ko', label=compnames[i])
#    plt.xticks(l, compnames, rotation=90)

# %%
for i in l:
    plt.plot(l[i], comparison_nitrite[i], 'ko', label=compnames[i])
    plt.xticks(l, compnames, rotation=90)
    plt.ylabel('nitrite')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-6f38b57befd4> in <module>()
# ----> 1 for i in l:
#       2     plt.plot(l[i], comparison_nitrite[i], 'ko', label=compnames[i])
#       3     plt.xticks(l, compnames, rotation=90)
#       4     plt.ylabel('nitrite')
#
# NameError: name 'l' is not defined

# %%
for i in l:
    plt.plot(l[i], comparison_nitrate[i], 'ko', label=compnames[i])
    plt.xticks(l, compnames, rotation=90)
    plt.ylabel('nitrate')

# %%
ynp = pd.read_csv('YNP_2017_3.15.csv')
ynp = ynp[ynp.columns.drop(list(ynp.filter(regex='Unnamed')))]

### converting values to numerics
pd.to_numeric(ynp['pH'])
#pd.to_numeric(ynp['DIC'])
pd.to_numeric(ynp['NO2-.1'])
pd.to_numeric(ynp['NO3-.1'])
pd.to_numeric(ynp['NH4+.1'])
pd.to_numeric(ynp['Cl-.1'])
pd.to_numeric(ynp['SO4-2.1'])
pd.to_numeric(ynp['F-.1'])
pd.to_numeric(ynp['Br-.1'])
pd.to_numeric(ynp['Li+.1'])
pd.to_numeric(ynp['Na+.1'])
pd.to_numeric(ynp['K+.1'])
pd.to_numeric(ynp['Mg+2.1'])
pd.to_numeric(ynp['Ca+2.1'])



clean_ynp = ynp.loc[(ynp['pH'] >= 6.) & (ynp['pH'] <= 8)]
### drops all columns with Unnamed
clean_ynp = clean_ynp[clean_ynp.columns.drop(list(clean_ynp.filter(regex='Unnamed')))]

# %%
ynp['DIC'][235] = 0
pd.to_numeric(ynp['DIC'])
# Out:
# 0         NaN
# 1         NaN
# 2        0.20
# 3        7.20
# 4       35.00
# 5       21.00
# 6       39.80
# 7        1.60
# 8         NaN
# 9       13.60
# 10      48.50
# 11      33.00
# 12      62.00
# 13       0.05
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21       0.20
# 22      12.70
# 23       9.30
# 24      15.60
# 25      19.70
# 26        NaN
# 27      11.60
# 28       6.40
# 29      18.90
#         ...
# 397     29.70
# 398     53.00
# 399     10.80
# 400       NaN
# 401       NaN
# 402       NaN
# 403       NaN
# 404      2.80
# 405      2.70
# 406      4.60
# 407      0.80
# 408      3.70
# 409     49.60
# 410     42.80
# 411      6.10
# 412      2.70
# 413    112.00
# 414       NaN
# 415      0.10
# 416      4.80
# 417      7.10
# 418     72.00
# 419      1.40
# 420      7.20
# 421    120.90
# 422       NaN
# 423       NaN
# 424       NaN
# 425       NaN
# 426       NaN
# ...

# %%
clean_names = clean_ynp['Sample Location']
clean_names.index = range(len(clean_names))
clean_pH = clean_ynp['pH']
clean_pH.index = range(len(clean_pH))
clean_temp = clean_ynp['Cond Temp']
clean_temp.index = range(len(clean_temp))
clean_DIC = clean_ynp['DIC']
clean_DIC.index = range(len(clean_DIC))
clean_ammonium = clean_ynp['NH4+.1']
clean_ammonium.index = range(len(clean_ammonium))
clean_nitrite = clean_ynp['NO2-.1']
clean_nitrite.index = range(len(clean_nitrite))
clean_nitrate = clean_ynp['NO3-.1']
clean_nitrate.index = range(len(clean_nitrate))
clean_chloride = clean_ynp['Cl-.1']
clean_chloride.index = range(len(clean_chloride))
clean_sulfate = clean_ynp['SO4-2.1']
clean_sulfate.index = range(len(clean_sulfate))
clean_flouride = clean_ynp['F-.1']
clean_flouride.index = range(len(clean_flouride))
clean_bromide = clean_ynp['Br-.1']
clean_bromide.index = range(len(clean_bromide))
clean_lithium = clean_ynp['Li+.1']
clean_lithium.index = range(len(clean_lithium))
clean_sodium = clean_ynp['Na+.1']
clean_sodium.index = range(len(clean_sodium))
clean_potassium = clean_ynp['K+.1']
clean_potassium.index = range(len(clean_potassium))
clean_magnesium = clean_ynp['Mg+2.1']
clean_magnesium.index = range(len(clean_magnesium))
clean_calcium = clean_ynp['Ca+2.1']
clean_calcium.index = range(len(clean_calcium))

# %%
z = np.arange(len(clean_pH))

plt.plot(spirea_pH[0], 'go', label='Heart of Joy')
plt.plot(spirea_pH[1], 'yo', label='Hat Stew')
plt.plot(spirea_pH[2], 'bo', label='Green Machine')
plt.plot(spirea_pH[3], 'co', label='Bubble Boy')
for i in z:
    plt.plot(i, clean_pH[i], 'ko')
plt.title('pH in YNP 2017 samples')
plt.legend(loc='best')

# %%
for i in z:
    plt.plot(clean_temp[i], clean_nitrite[i], 'ko')
#plt.plot(spirea_temp[0], spirea_nitrite[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_nitrite[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_nitrite[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_nitrite[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('NO2- (mol/kg)')
plt.title('Nitrite')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-nitrite')

# %%
clean_nitrite.sort_values(ascending=False)
clean_names[15]
# Out:
# "Vince's Man Cave"

# %%
for i in z:
    plt.plot(clean_temp[i], clean_nitrate[i], 'ko')
#plt.plot(spirea_temp[0], spirea_nitrite[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_nitrate[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_nitrate[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_nitrate[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('NO3- (mol/kg)')
plt.title('Nitrate')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-nitrate')

# %%
### spirea creek in pH/temp
for i in z:
    plt.plot(clean_temp[i], clean_pH[i], 'ko')
plt.plot(spirea_temp[0], spirea_pH[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_pH[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_pH[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_pH[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('pH')
plt.title('Temperature vs. pH')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-pH')

# %%
### spirea creek in cl-/so4-2
for i in z:
    plt.plot(clean_chloride[i], clean_sulfate[i], 'ko')
plt.plot(spirea_chloride[0], spirea_sulfate[0], 'ro', label='Heart of Joy')
plt.plot(spirea_chloride[1], spirea_sulfate[1], 'mo', label='Hat Stew')
plt.plot(spirea_chloride[2], spirea_sulfate[2], 'yo', label='Green Machine')
plt.plot(spirea_chloride[3], spirea_sulfate[3], 'co', label='Bubble Boy')
plt.xlabel('Cl-')
plt.xscale('log')
plt.ylabel('SO4-2')
plt.yscale('log')
plt.title('Cl- vs. SO4-2')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_chloride_sulfate')

# %%
for i in z:
    plt.plot(clean_temp[i], clean_sulfate[i], 'ko')
plt.plot(spirea_temp[0], spirea_sulfate[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_sulfate[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_sulfate[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_sulfate[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('SO4-2 (mol/kg)')
plt.title('Sulfate')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-sulfate')

# %%
clean_sulfate.sort_values(ascending=False)
clean_names[2]
# Out:
# "Skippy's Bathtub OF"

# %%
for i in z:
    plt.plot(clean_temp[i], clean_chloride[i], 'ko')
plt.plot(spirea_temp[0], spirea_chloride[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_chloride[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_chloride[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_chloride[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('Cl- (mol/kg)')
plt.title('Chloride')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-chloride')

# %%
for i in z:
    plt.plot(clean_temp[i], clean_flouride[i], 'ko')
plt.plot(spirea_temp[0], spirea_flouride[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_flouride[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_flouride[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_flouride[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature')
plt.ylabel('F- (mol/kg)')
plt.title('Flouride')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-flouride')

# %%
clean_flouride.sort_values(ascending=False)
clean_names[2:4]
# Out:
# 2    Skippy's Bathtub OF
# 3                Avocado
# Name: Sample Location, dtype: object

# %%
for i in z:
    plt.plot(clean_temp[i], clean_bromide[i], 'ko')
plt.plot(spirea_temp[0], spirea_bromide[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_bromide[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_bromide[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_bromide[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('Br- (mol/kg)')
plt.title('Bromide')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-bromide')

# %%
for i in z:
    plt.plot(clean_temp[i], clean_lithium[i], 'ko')
plt.plot(spirea_temp[0], spirea_lithium[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_lithium[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_lithium[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_lithium[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('Li+ (mol/kg)')
plt.title('Lithium')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-lithium')

# %%
for i in z:
    plt.plot(clean_temp[i], clean_sodium[i], 'ko')
plt.plot(spirea_temp[0], spirea_sodium[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_sodium[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_sodium[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_sodium[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('Na+ (mol/kg)')
plt.title('Sodium')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-sodium')

# %%
for i in z:
    plt.plot(clean_temp[i], clean_potassium[i], 'ko')
plt.plot(spirea_temp[0], spirea_potassium[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_potassium[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_potassium[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_potassium[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('K+ (mol/kg)')
plt.title('Potassium')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-potassium')

# %%
for i in z:
    plt.plot(clean_temp[i], clean_magnesium[i], 'ko')
plt.plot(spirea_temp[0], spirea_magnesium[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_magnesium[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_magnesium[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_magnesium[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('Mg+2 (mol/kg)')
plt.title('Magnesium')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-magnesium')

# %%
clean_magnesium.sort_values(ascending=False)
clean_names[48:50]
clean_pH[48:50]
# Out:
# 48    6.458
# 49    6.200
# Name: pH, dtype: float64

# %%
for i in z:
    plt.plot(clean_temp[i], clean_calcium[i], 'ko')
plt.plot(spirea_temp[0], spirea_calcium[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_calcium[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_calcium[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_calcium[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('Ca+2 (mol/kg)')
plt.title('Calcium')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-calcium')

# %%
clean_calcium.sort_values(ascending=False)
# Out:
# 48    0.008140
# 49    0.006090
# 36    0.001110
# 37    0.000811
# 23    0.000408
# 22    0.000395
# 24    0.000355
# 32    0.000355
# 25    0.000351
# 31    0.000336
# 29    0.000323
# 52    0.000257
# 30    0.000245
# 6     0.000241
# 7     0.000229
# 14    0.000222
# 12    0.000214
# 44    0.000173
# 45    0.000169
# 13    0.000159
# 39    0.000156
# 2     0.000146
# 9     0.000115
# 10    0.000112
# 4     0.000111
# 11    0.000110
# 5     0.000107
# 38    0.000098
# 40    0.000097
# 46    0.000097
# 50    0.000095
# 3     0.000082
# 8     0.000080
# 51    0.000043
# 41    0.000035
# 20    0.000023
# 21    0.000022
# 15    0.000020
# 18    0.000013
# 19    0.000012
# 0          NaN
# 1          NaN
# 16         NaN
# 17         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 33         NaN
# 34         NaN
# 35         NaN
# 42         NaN
# 43         NaN
# 47         NaN
# 53         NaN
# Name: Ca+2.1, dtype: float64

# %%
for i in z:
    plt.plot(clean_temp[i], clean_ammonium[i], 'ko')
plt.plot(spirea_temp[0], spirea_ammonium[0], 'ro', label='Heart of Joy')
plt.plot(spirea_temp[1], spirea_ammonium[1], 'mo', label='Hat Stew')
plt.plot(spirea_temp[2], spirea_ammonium[2], 'yo', label='Green Machine')
plt.plot(spirea_temp[3], spirea_ammonium[3], 'co', label='Bubble Boy')
plt.xlabel('Temperature (°C)')
plt.ylabel('NH4+ (mol/kg)')
plt.title('Ammonium')
plt.legend(loc='best')
plt.tight_layout()
plt.savefig('full_temp-ammonium')

# %%
clean_calcium.sort_values(ascending=False)
clean_magnesium.sort_values(ascending=False)
clean_names[48:50]
## calcium and magnesium abberant values are Fracking Calcite and Blue Steel
## abberant nitrite/nitrate values are Vince's Man Cave [15]
